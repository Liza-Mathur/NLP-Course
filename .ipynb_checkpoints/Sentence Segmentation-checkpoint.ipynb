# %% [markdown]
# Sentence Segmentation.

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp(u"This is first sentence. This is second sentence. This is my last sentence.")

# %%
for sent in doc.sents:
    print(sent)
# Out:
# This is first sentence.
# This is second sentence.
# This is my last sentence.

# %% [markdown]
# doc.sents[0] - will fail because its not a list, its a generator.

# %% [markdown]
# Pass it to list to make list of sentences -

# %%
list(doc.sents)
# Out:
# [This is first sentence., This is second sentence., This is my last sentence.]

# %% [markdown]
# But maybe we wanna segment on coma and not full stop or something else - we use custom segmentation

# %%
doc = nlp(u'"Management is doing the right things; leadership is doing the right things." -Peter Drucker')

# %%
doc.text
# Out:
# '"Management is doing the right things; leadership is doing the right things." -Peter Drucker'

# %%
for sent in doc.sents:
    print(sent)
# Out:
# "Management is doing the right things; leadership is doing the right things."
# -Peter Drucker

# %% [markdown]
# 1. Add segmentation rule
# 2. Change the rule

# %%
#1 - 
from spacy.language import Language
@Language.component("set_custom_boundaries")
def set_custom_boundaries(doc):
    for token in doc[:-1]:
        if token.text == ';':
            doc[token.i+1].is_sent_start = True
    return doc

# %%
nlp.add_pipe("set_custom_boundaries", before='parser')
# Out:
# <function __main__.set_custom_boundaries(doc)>

# %%
nlp.pipe_names
# Out:
# ['tok2vec',
#  'tagger',
#  'set_custom_boundaries',
#  'parser',
#  'attribute_ruler',
#  'lemmatizer',
#  'ner']

# %%
doc4 = nlp(u'"Management is doing the right things; leadership is doing the right things." -Peter Drucker')

# %%
for sent in doc4.sents:
    print(sent)
# Out:
# "Management is doing the right things;
# leadership is doing the right things."
# -Peter Drucker

# %% [markdown]
# This added a rule. But now I wanna remove defaults and all new rule

# %%
nlp = spacy.load('en_core_web_sm')

# %%
mystring = u"This is a sentence. This is another \n\n This is a third \n sentence."

# %%
print(mystring)
# Out:
# This is a sentence. This is another
#
#  This is a third
#  sentence.

# %%
doc = nlp(mystring)

# %%
for sent in doc.sents:
    print(sent)
# Out:
# This is a sentence.
# This is another
#
#  This is a third
#  sentence.

# %% [markdown]
# But I want new line as a new sentence

# %%
from spacy.pipeline import Sentencizer

# %%
@Language.component("split_on_newlines")
def split_on_newlines(doc):
    start = 0
    seen_newline = False
    for word in doc:
        if seen_newline :
            yield doc[start:word.i]
            start = word.i
            seen_newline = False
        elif word.text.startswith("\n"):
            seen_newline = True
    return doc

# %%
nlp.add_pipe("split_on_newlines" , before="parser")
doc = nlp(mystring)
for sentence in doc.sents:
    print(sentence)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 2
#       1 nlp.add_pipe("split_on_newlines" , before="parser")
# ----> 2 doc = nlp(mystring)
#       3 for sentence in doc.sents:
#       4     print(sentence)
#
# File ~\anaconda3\Lib\site-packages\spacy\language.py:1060, in Language.__call__(self, text, disable, component_cfg)
#    1058         error_handler(name, proc, [doc], e)
#    1059     if not isinstance(doc, Doc):
# -> 1060         raise ValueError(Errors.E005.format(name=name, returned_type=type(doc)))
#    1061 return doc
#
# ValueError: [E005] Pipeline component 'split_on_newlines' returned <class 'generator'> instead of a Doc. If you're using a custom component, maybe you forgot to return the processed Doc?
